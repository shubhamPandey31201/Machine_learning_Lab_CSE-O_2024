# %% [markdown]
# # Machine Learning Lab-2 - AP21110010940
# # Introduction to Matplotlib:

# %% [markdown]
# 1. Create a figure object called fig using plt.figure() , Use add_axes to add an axis to the figure
# canvas at [0,0,1,1]. Call this new axis ax.

# %%
import matplotlib.pyplot as plt
import pandas as pd
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
ax.plot(x, y)

ax.set_xlabel('X-Axis')
ax.set_ylabel('Y-Axis')
ax.set_title('Plot on Custom Axis')
plt.show()

# %% [markdown]
# 2.Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and
# [0.2,0.5,.2,.2] respectively.

# %%
import matplotlib.pyplot as plt
import pandas as pd

fig = plt.figure()

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.2, 0.5, 0.2, 0.2])

x1 = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]
ax1.plot(x1, y1, label='ax1')

x2 = [1, 2, 3, 4, 5]
y2 = [10, 8, 6, 4, 2]
ax2.plot(x2, y2, color='red', label='ax2')
ax1.set_xlabel('X-axis (ax1)')
ax1.set_ylabel('Y-axis (ax1)')
ax1.set_title('Plot on ax1')
ax1.legend()

ax2.set_xlabel('X-axis (ax2)')
ax2.set_ylabel('Y-axis (ax2)')
ax2.set_title('Plot on ax2')
ax2.legend()

plt.show()

# %% [markdown]
# 3.Write a Python program to draw a line with suitable label in the x axis, y axis and a title.

# %%
import matplotlib.pyplot as plt
import pandas as pd
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot with Labels')

plt.show()

# %% [markdown]
# 4.Write a Python program to draw a line using given axis values taken from a text file, with
# suitable label in the x axis, y axis and a title.

# %%
import matplotlib.pyplot as plt

file_path = 'data.txt'  
x_values = []
y_values = []

with open(file_path, 'r') as file:
    for line in file:
        x, y = line.strip().split(',')
        x_values.append(int(x))
        y_values.append(int(y))

plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, 'bo-', label='Data points')  

plt.xlabel('X Axis') 
plt.ylabel('Y Axis')
plt.title('Line Plot from Data in Text File') 
plt.legend()

plt.show()

# %% [markdown]
# 5.Write a Python program to plot two or more lines with legends, different widths and colors.

# %%
import matplotlib.pyplot as plt
import pandas as pd

x = [1, 2, 3, 4, 5]
y1 = [2, 4, 6, 8, 10]
y2 = [1, 2, 1, 2, 1]

plt.plot(x, y1, color='green', linewidth=2, label='Line 1')

plt.plot(x, y2, color='red', linewidth=3, label='Line 2')

plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Multiple Lines with Legends')

plt.legend()

plt.show()

# %% [markdown]
# 6.Write a Python program to plot quantities which have an x and y position.

# %%
import matplotlib.pyplot as plt

x_positions = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4.5, 6, 8.5]
y_positions = [2, 3, 4, 2, 3.5, 4, 5, 1.5, 2.5, 4, 5, 4.5]

plt.figure(figsize=(10, 6))
plt.scatter(x_positions, y_positions, color='blue', marker='o', label='Positions')

plt.xlabel('X Position')
plt.ylabel('Y Position')
plt.title('Scatter Plot of Quantities with X and Y Positions')
plt.legend()

plt.show()

# %% [markdown]
# 7.Create plot using subplots(), scatter, and some other methods on the Axes object:

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 30) 
y1 = np.sin(x)
y2 = np.cos(x)

fig, axs = plt.subplots(1, 2, figsize=(14, 5))  

axs[0].scatter(x, y1, color='blue', label='sin(x)')
axs[0].set_title('Scatter Plot')
axs[0].set_xlabel('X')
axs[0].set_ylabel('Y')
axs[0].legend()

axs[1].plot(x, y2, linestyle='-', marker='o', color='red', label='cos(x)')
axs[1].set_title('Line Plot')
axs[1].set_xlabel('X')
axs[1].set_ylabel('Y')
axs[1].legend()

plt.tight_layout()

plt.show()

# %% [markdown]
# 8.Generate random data for x and y and create a scatter plot using Matplotlib.

# %%
import matplotlib.pyplot as plt
import pandas as pd

np.random.seed(42)  
num_points = 50
x_positions = np.random.rand(num_points) * 10  
y_positions = np.random.rand(num_points) * 20  

plt.scatter(x_positions, y_positions, color='violet', marker='o', label='Random Data')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Random Scatter Plot')

plt.legend()

plt.show()

# %% [markdown]
# 9.Create a bar chart to compare the sales of different products. You can use fictional data or come up
# with your own dataset.

# %%
import matplotlib.pyplot as plt
import pandas as pd

products = ['Product A', 'Product B', 'Product C', 'Product D', 'Product E']
sales = [350, 500, 200, 700, 400]

plt.bar(products, sales, color='yellow')

plt.xlabel('Products')
plt.ylabel('Sales (Units)')
plt.title('Product Sales Comparison')

plt.show()

# %% [markdown]
# 10.Generate a random dataset and create a histogram using Matplotlib to visualize the distribution of
# the data.

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.randn(1000)

plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, color='skyblue', edgecolor='black')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Randomly Generated Data')

plt.show()

# %% [markdown]
# 11.Create a pie chart to represent the distribution of expenses in a budget. Use fictional data or create
# your own.

# %%
import matplotlib.pyplot as plt
import pandas as pd

categories = ['Rent', 'Transport', 'Food', 'Entertainment', 'Utilities']
expenses = [1000, 600, 300, 400, 200]

plt.pie(expenses, labels=categories, autopct='%1.1f%%', colors=['blue', 'lightcoral', 'lightgreen', 'lightpink', 'red'], startangle=90)

plt.title('Expense Distribution in Budget')

plt.show()
